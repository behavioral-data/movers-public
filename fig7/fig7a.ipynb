# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import datetime
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

def generate_default_plot_env():
    sns.set(font_scale=1.4, style="whitegrid")
    matplotlib.rcParams['pdf.fonttype'] = 42
    matplotlib.rcParams['ps.fonttype'] = 42
    matplotlib.rc('font', family='sans-serif') 
    matplotlib.rc('font', serif='Helvetica Neue') 
    matplotlib.rc('text', usetex='false') 
    matplotlib.rcParams.update({'font.size': 22})
    
    plt.rcParams['pdf.fonttype'] = 42
    plt.rcParams['ps.fonttype'] = 42
    plt.rc('font', family='sans-serif') 
    plt.rc('font', serif='Helvetica Neue') 
    plt.rc('text', usetex='false') 
    plt.rcParams.update({'font.size': 22})

# %%
generate_default_plot_env()

# %%
move_months_df = pd.read_csv("../data/move_months.csv")

# %%
def to_month_str(month):
    date = datetime.datetime(2000, month, 1)
    return date.strftime('%b')

fig, ax = plt.subplots()
ax.grid(False)
ax = sns.barplot(data=move_months_df, x='Move Month', y='# Steps Check-ins', 
                 color='#3f6d32', order=[to_month_str(i) for i in range(1, 13)])
ax.set(xlabel='Month of Move', ylabel='Number of Days Tracked')
ax.xaxis.set_ticklabels(ax.xaxis.get_ticklabels(), rotation=0)

fig.set_size_inches(7, 5)
plt.tight_layout()
plt.savefig('../output/fig7a.pdf', dpi=300)
